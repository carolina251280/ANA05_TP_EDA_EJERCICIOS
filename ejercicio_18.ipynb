# %% [markdown]
# Crear 2 matrices y realizar la multiplicación entre ambas.

# %%
import numpy as np

# %%
matriz1 = np.array([[1, 2, 3],
                    [4, 5, 6]])


matriz2 = np.array([[7, 8, 11],
                    [9, 10, 12]])

print("Resultado de la suma:")
print(matriz1 + matriz2)
# Out:
# Resultado de la suma:
# [[ 8 10 14]
#  [13 15 18]]
